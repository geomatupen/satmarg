# %%
# !pip install --upgrade satmarg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: satmarg in c:\users\rog\appdata\roaming\python\python312\site-packages (0.2.1)
# Collecting satmarg
#   Downloading satmarg-0.2.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: skyfield in c:\users\rog\appdata\roaming\python\python312\site-packages (from satmarg) (1.52)
# Requirement already satisfied: numpy in c:\users\rog\appdata\roaming\python\python312\site-packages (from satmarg) (1.26.4)
# Requirement already satisfied: pandas in c:\anaconda\lib\site-packages (from satmarg) (2.2.2)
# Requirement already satisfied: requests in c:\users\rog\appdata\roaming\python\python312\site-packages (from satmarg) (2.32.3)
# Requirement already satisfied: datetime in c:\users\rog\appdata\roaming\python\python312\site-packages (from satmarg) (5.5)
# Requirement already satisfied: zope.interface in c:\anaconda\lib\site-packages (from datetime->satmarg) (5.4.0)
# Requirement already satisfied: pytz in c:\anaconda\lib\site-packages (from datetime->satmarg) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rog\appdata\roaming\python\python312\site-packages (from pandas->satmarg) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\lib\site-packages (from pandas->satmarg) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rog\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->satmarg) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rog\appdata\roaming\python\python312\site-packages (from requests->satmarg) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rog\appdata\roaming\python\python312\site-packages (from requests->satmarg) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rog\appdata\roaming\python\python312\site-packages (from requests->satmarg) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rog\appdata\roaming\python\python312\site-packages (from requests->satmarg) (2025.1.31)
# Requirement already satisfied: jplephem>=2.13 in c:\users\rog\appdata\roaming\python\python312\site-packages (from skyfield->satmarg) (2.22)
# Requirement already satisfied: sgp4>=2.13 in c:\users\rog\appdata\roaming\python\python312\site-packages (from skyfield->satmarg) (2.24)
# Requirement already satisfied: setuptools in c:\users\rog\appdata\roaming\python\python312\site-packages (from zope.interface->datetime->satmarg) (78.1.0)
# Downloading satmarg-0.2.2-py3-none-any.whl (17 kB)
# Installing collected packages: satmarg
#   Attempting uninstall: satmarg
#     Found existing installation: satmarg 0.2.1
#     Uninstalling satmarg-0.2.1:
#       Successfully uninstalled satmarg-0.2.1
# Successfully installed satmarg-0.2.2

# %%
from satmarg.core import get_precise_overpasses

# Location: example is Kathmandu
df = get_precise_overpasses(
    lat= 47.899167,
    lon= 17.007472,
    # lat = 27.700769,
    # lon = 85.300140,
    start_date="2025-09-22",
    end_date="2025-11-22",
    satellites="SENTINEL-3A, SENTINEL-3B, LANDSAT 8, LANDSAT 9, ISS (ZARYA)",
    step_seconds=1,
    # max_angle_deg=0.6,
    max_angle_deg=None,
    output_format='csv' # options: csv, table, json
)

print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 from satmarg.core import get_precise_overpasses
#       3 # Location: example is Kathmandu
# ----> 4 df = get_precise_overpasses(
#       5     lat= 47.899167,
#       6     lon= 17.007472,
#       7     # lat = 27.700769,
#       8     # lon = 85.300140,
#       9     start_date="2025-09-22",
#      10     end_date="2025-11-22",
#      11     satellites="SENTINEL-3A, SENTINEL-3B, LANDSAT 8, LANDSAT 9, ISS (ZARYA)",
#      12     step_seconds=1,
#      13     # max_angle_deg=0.6,
#      14     max_angle_deg=None,
#      15     output_format='csv' # options: csv, table, json
#      16 )
#      18 print(df)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\satmarg\core.py:171, in get_precise_overpasses(lat, lon, start_date, end_date, satellites, step_seconds, max_angle_deg, output_format)
#     168 all_overpasses = []
#     170 for sat in all_satellites:
# --> 171     overpasses = find_overpasses(lat, lon, start_date, end_date, sat, all_satellites, step_seconds, max_angle_deg)
#     172     all_overpasses.extend(overpasses)
#     174 df = pd.DataFrame(all_overpasses)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\satmarg\core.py:114, in find_overpasses(lat, lon, start_date, end_date, satellite, satellites, step_seconds, max_angle_deg)
#     111 topocentric = (sat - observer).at(t[min_index])
#     112 alt, az, distance = topocentric.altaz()
# --> 114 if distances[min_index] < max_angle_deg:
#     115     results.append({
#     116         'date': closest_time.strftime('%Y-%m-%d %H:%M:%S'),
#     117         'Satellite': satellite,
#    (...)    122         'Range (km)': distance.km
#     123     })
#     125 dt += timedelta(days=1)
#
# TypeError: '<' not supported between instances of 'float' and 'NoneType'

# %%
from datetime import datetime
import os

today = datetime.today().date();
print(today)
output_dir = 'Outputs'
os.makedirs(output_dir, exist_ok=True)
df.to_csv(f"Outputs/prediction_{today}.csv", index=False)
print("Data added to CSV")
# Out:
# 2025-08-05
# Data added to CSV
